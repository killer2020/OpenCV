# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
def showImage( img ):
   cv2.imshow('image',img)
   cv2.waitKey(0)
   cv2.destroyAllWindows()
   cv2.waitKey(1)
   return

# %%
img = cv2.imread('shiwali.PNG')

print(img.shape)
# Out:
# (900, 1440, 3)

# %%
res = cv2.resize(img,None,fx=0.1,fy=0.1,interpolation = cv2.INTER_CUBIC)
showImage(res)
print(res.shape)
# Out:
# (90, 144, 3)

# %%
img = cv2.imread('Image1.jpg',0)
rows,cols=img.shape

M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))
showImage(dst)

# %%
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
print(M.shape)
# Out:
# (2, 3)

# %%
dst = cv2.warpAffine(img,M,(cols,rows))
showImage(dst)

# %%
img = cv2.imread('mesh.jpg')
rows,cols,ch = img.shape
print(img.shape)
pts1= np.float32([[50,50],[100,50],[50,125]])
pts2= np.float32([[10,100],[100,50],[75,145]])

M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img,M,(cols,rows))

#showImage(img)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
#showImage(dst)
# Out:
# (470, 437, 3)
# (<matplotlib.axes._subplots.AxesSubplot at 0x1373fb4e0>,
#  <matplotlib.image.AxesImage at 0x1375216d8>,
#  Text(0.5,1,'Output'))
