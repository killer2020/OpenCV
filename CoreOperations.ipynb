# %%
import numpy as np
import cv2

# %%
img = cv2.imread('shiwale.PNG')

# %%
img

# %%
print(img)
# Out:
# None

# %%
img = cv2.imread('shiwali.PNG')

# %%
print(img)

# %%
print(img.size)
# Out:
# 3888000

# %%
print(img.shape)
# Out:
# (900, 1440, 3)

# %%
px = img[500,500]
print(px)
# Out:
# [200 203 194]

# %%
blue = img[500,500,0]
print(blue)
# Out:
# 200

# %%
print(img.dtype)
# Out:
# uint8

# %%
def showImage(img):
    cv2.imshow('image',img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cv2.waitKey(1)

# %%
showImage(img)

# %%
face = img[0:200,0:200]
img[200:400,200:400] = face

# %%
showImage(img)

# %%
img[:,:,2]=0

# %%
showImage(img)

# %%
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('shiwali.PNG')

BLUE = [255,0,0]

constant = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)
#showImage(constant)
#sets size of plot
plt.figure(figsize=(40, 16))

plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()
